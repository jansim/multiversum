# %%
settings = {
    "dimensions": {
        "x": "A",
        "y": "B",
    }
}

# %%
# Parameters
settings = "{\"dimensions\": {\"x\": \"A\", \"y\": \"A\"}, \"output_dir\": \"/home/runner/work/multiversum/multiversum/tests/temp/test_MultiverseAnalysis_noteboook_timeout\", \"run_no\": 1, \"seed\": 80539, \"universe_id\": \"ffa9b24041c120dd216c98b8b02f581c\"}"

# %%
from multiversum import Universe

universe = Universe(
    settings=settings,
)

# Get the parsed universe settings
dimensions = universe.dimensions
# Out:
# Setting seed to 80539 (in: [random, numpy.random]).

# %%
import pandas as pd

final_data = pd.DataFrame({"value": [ord(dimensions["x"]) + ord(dimensions["y"])]})

# %%
# Sleep for 3 secs
import time

time.sleep(15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Sleep for 3 secs
#       2 import time
# ----> 4 time.sleep(15)
#
# KeyboardInterrupt:

# %%
universe.save_data(final_data)
