# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [5]</a>'.</span>

# %%
settings = {
    "dimensions": {
        "x": "A",
        "y": "B",
    }
}

# %%
# Parameters
settings = "{\"dimensions\": {\"x\": \"A\", \"y\": \"A\"}, \"output_dir\": \"/home/runner/work/multiversum/multiversum/tests/temp/test_MultiverseAnalysis_noteboook_error\", \"run_no\": 1, \"seed\": 80539, \"universe_id\": \"ffa9b24041c120dd216c98b8b02f581c\"}"

# %%
from multiversum import Universe

universe = Universe(
    settings=settings,
)

# Get the parsed universe settings
dimensions = universe.dimensions
# Out:
# Setting seed to 80539 (in: [random, numpy.random]).

# %%
import pandas as pd

final_data = pd.DataFrame({"value": [ord(dimensions["x"]) + ord(dimensions["y"])]})

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
if dimensions["x"] == dimensions["y"]:
    raise ValueError("The dimensions must not be the same")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 if dimensions["x"] == dimensions["y"]:
# ----> 2     raise ValueError("The dimensions must not be the same")
#
# ValueError: The dimensions must not be the same

# %%
universe.save_data(final_data)
