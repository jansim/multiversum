# %%
settings = {
    "dimensions": {
        "x": "A",
        "y": "B",
    }
}

# %%
# Parameters
settings = "{\"dimensions\": {\"x\": \"A\", \"y\": \"B\"}, \"output_dir\": \"/home/runner/work/multiversum/multiversum/tests/temp/test_MultiverseAnalysis_check_missing_universes_without_errors\", \"run_no\": 1, \"seed\": 80539, \"universe_id\": \"47899ae546a9854ebfe2de7396eff9fa\"}"

# %%
from multiversum import Universe

universe = Universe(
    settings=settings,
)

# Get the parsed universe settings
dimensions = universe.dimensions
# Out:
# Setting seed to 80539 (in: [random, numpy.random]).

# %%
import pandas as pd

final_data = pd.DataFrame({"value": [ord(dimensions["x"]) + ord(dimensions["y"])]})

# %%
universe.save_data(final_data)
# Out:
# Stopping execution_time clock.
